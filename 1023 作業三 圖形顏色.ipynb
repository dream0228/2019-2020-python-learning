# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
π=np.pi

# %%
x=np.linspace(-5*π,5*π,9487)
y=np.sin(x)/6

# %%
plt.scatter(x[y<0],y[y<0],c='#FFD700')
plt.plot(x,y)
