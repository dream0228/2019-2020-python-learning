# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #  各類運動消耗熱量表

# %%
df=pd.read_csv("https://drive.google.com/uc?export=download&confirm=jeak&id=1c8ywL-A9Vo7FWwIRYyINJZJlAPs0n99Z")

# %%
df
# Out:
#                  運動項目   消耗熱量(大卡/公斤體重/小時)  40公斤運動30分鐘所消耗的熱量 (大卡)  \
# 0           慢走(4公里/小時)               3.5                     70
# 1      快走、健走(6.0公里/小時)               5.5                    110
# 2                  下樓梯               3.2                     64
# 3                  上樓梯               8.4                    168
# 4           慢跑(8公里/小時)               8.2                    164
# 5          快跑(12公里/小時)              12.7                    254
# 6          快跑(16公里/小時)              16.8                    336
# 7   騎腳踏車(一般速度，10公里/小時)               4.0                     80
# 8      騎腳踏車(快，20公里/小時)               8.4                    168
# 9     騎腳踏車(很快，30公里/小時)              12.6                    252
# 10                  拖地               3.7                     74
# 11                  園藝               4.2                     84
# 12     使用工具製造或修理(如水電工)               5.3                    106
# 13         耕種、牧場、漁業、林業               7.4                    148
# ...

# %%
df.describe()
# Out:
#        消耗熱量(大卡/公斤體重/小時)  40公斤運動30分鐘所消耗的熱量 (大卡)  50公斤運動30分鐘所消耗的熱量 (大卡)  \
# count         36.000000              36.000000              36.000000
# mean           6.538889             130.777778             163.472222
# std            3.246121              64.922420              81.153025
# min            3.000000              60.000000              75.000000
# 25%            4.150000              83.000000             103.750000
# 50%            5.400000             108.000000             135.000000
# 75%            8.325000             166.500000             208.125000
# max           16.800000             336.000000             420.000000
#
#        60公斤運動30分鐘所消耗的熱量 (大卡)  70公斤運動30分鐘所消耗的熱量 (大卡)
# count              36.000000              36.000000
# mean              196.166667             228.861111
# std                97.383630             113.614235
# min                90.000000             105.000000
# 25%               124.500000             145.250000
# ...

# %% [markdown]
# ### 消耗熱量排序(高至低)

# %%
df.sort_values(by="消耗熱量(大卡/公斤體重/小時)",ascending=False)
# Out:
#                  運動項目   消耗熱量(大卡/公斤體重/小時)  40公斤運動30分鐘所消耗的熱量 (大卡)  \
# 6          快跑(16公里/小時)              16.8                    336
# 5          快跑(12公里/小時)              12.7                    254
# 35               跳繩(快)              12.6                    252
# 9     騎腳踏車(很快，30公里/小時)              12.6                    252
# 28              游泳(較快)              10.0                    200
# 34               跳繩(慢)               8.4                    168
# 3                  上樓梯               8.4                    168
# 14                搬運重物               8.4                    168
# 8      騎腳踏車(快，20公里/小時)               8.4                    168
# 30              籃球(全場)               8.3                    166
# 4           慢跑(8公里/小時)               8.2                    164
# 33                  足球               7.7                    154
# 13         耕種、牧場、漁業、林業               7.4                    148
# 31                有氧舞蹈               6.8                    136
# ...

# %% [markdown]
# #### 消耗熱量前五的運動

# %%
df.sort_values(by="消耗熱量(大卡/公斤體重/小時)",ascending=False).head()
# Out:
#                運動項目   消耗熱量(大卡/公斤體重/小時)  40公斤運動30分鐘所消耗的熱量 (大卡)  \
# 6        快跑(16公里/小時)              16.8                    336
# 5        快跑(12公里/小時)              12.7                    254
# 35             跳繩(快)              12.6                    252
# 9   騎腳踏車(很快，30公里/小時)              12.6                    252
# 28            游泳(較快)              10.0                    200
#
#     50公斤運動30分鐘所消耗的熱量 (大卡)  60公斤運動30分鐘所消耗的熱量 (大卡)  70公斤運動30分鐘所消耗的熱量 (大卡)
# 6                   420.0                    504                  588.0
# 5                   317.5                    381                  444.5
# 35                  315.0                    378                  441.0
# 9                   315.0                    378                  441.0
# 28                  250.0                    300                  350.0

# %% [markdown]
# #### 消耗熱量末五的運動

# %%
df.sort_values(by="消耗熱量(大卡/公斤體重/小時)",ascending=False).tail()
# Out:
#          運動項目   消耗熱量(大卡/公斤體重/小時)  40公斤運動30分鐘所消耗的熱量 (大卡)  \
# 0   慢走(4公里/小時)               3.5                     70
# 2          下樓梯               3.2                     64
# 18          飛盤               3.2                     64
# 16   跳舞(慢)、元極舞               3.1                     62
# 15          瑜珈               3.0                     60
#
#     50公斤運動30分鐘所消耗的熱量 (大卡)  60公斤運動30分鐘所消耗的熱量 (大卡)  70公斤運動30分鐘所消耗的熱量 (大卡)
# 0                    87.5                    105                  122.5
# 2                    80.0                     96                  112.0
# 18                   80.0                     96                  112.0
# 16                   77.5                     93                  108.5
# 15                   75.0                     90                  105.0
