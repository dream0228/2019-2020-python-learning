# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-38,38,100)

# %%
y=np.tan(x)*x

# %%
y[y>50]=np.inf
y[y<-50]=np.inf

# %%
plt.xkcd()

# %%
plt.plot(x,y)
